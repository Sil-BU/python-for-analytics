# %%
import pandas as pd

df = pd.read_csv("./contents/titanic.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.shape)  #prints the shape of DataFrame - rows * columns
# Out:
# (891, 12)

# %%
print(df.columns)  #returns the column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum() / df.shape[0] * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df=df.drop(['Cabin'],axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df['Embarked'].fillna(df['Embarked'].mode().item(),inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df=df.rename(columns={'Sex':'Gender','Name':'Full Name'})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['last_name']=df['Full Name'].apply(lambda x: x.split(',')[0])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  last_name
# 0        1      0         A/5 21171   7.2500        S     Braund
# 1        1      0          PC 17599  71.2833        C    Cumings
# 2        0      0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3        1      0            113803  53.1000        S   Futrelle
# 4        0      0            373450   8.0500        S      Allen
# ..     ...    ...               ...      ...      ...        ...
# 886      0      0            211536  13.0000        S   Montvila
# 887      0      0            112053  30.0000        S     Graham
# 888      1      2        W./C. 6607  23.4500        S   Johnston
# 889      0      0            111369  30.0000        C       Behr
# 890      0      0            370376   7.7500        Q     Dooley
#
# [891 rows x 12 columns]

# %%
df['first_name']=df['Full Name'].apply(lambda x: ' '.join(x.split(',')[1:]))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  last_name  \
# 0        1      0         A/5 21171   7.2500        S     Braund
# 1        1      0          PC 17599  71.2833        C    Cumings
# 2        0      0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3        1      0            113803  53.1000        S   Futrelle
# 4        0      0            373450   8.0500        S      Allen
# ..     ...    ...               ...      ...      ...        ...
# 886      0      0            211536  13.0000        S   Montvila
# 887      0      0            112053  30.0000        S     Graham
# 888      1      2        W./C. 6607  23.4500        S   Johnston
# 889      0      0            111369  30.0000        C       Behr
# 890      0      0            370376   7.7500        Q     Dooley
#
#                                       first_name
# 0                                Mr. Owen Harris
# 1     Mrs. John Bradley (Florence Briggs Thayer)
# 2                                    Miss. Laina
# 3             Mrs. Jacques Heath (Lily May Peel)
# 4                              Mr. William Henry
# ..                                           ...
# 886                                  Rev. Juozas
# 887                         Miss. Margaret Edith
# 888               Miss. Catherine Helen "Carrie"
# 889                              Mr. Karl Howell
# 890                                  Mr. Patrick
#
# [891 rows x 13 columns]

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  last_name  \
# 0      0         A/5 21171   7.2500        S     Braund
# 1      0          PC 17599  71.2833        C    Cumings
# 2      0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3      0            113803  53.1000        S   Futrelle
# 4      0            373450   8.0500        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
row=dict({'Age':24,'Full Name':'Rohith','Survived':'Y'})
row
# Out:
# {'Age': 24, 'Full Name': 'Rohith', 'Survived': 'Y'}

# %%
df=df.append(row,ignore_index=True)
df
# Out:
# /var/folders/gl/321bd3r9019_q1gmsxg_0gph0000gn/T/ipykernel_63539/3456989694.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(row,ignore_index=True)
#      PassengerId Survived  Pclass  \
# 0            1.0        0     3.0
# 1            2.0        1     1.0
# 2            3.0        1     3.0
# 3            4.0        1     1.0
# 4            5.0        0     3.0
# ..           ...      ...     ...
# 887        888.0        1     1.0
# 888        889.0        0     3.0
# 889        890.0        1     1.0
# 890        891.0        0     3.0
# 891          NaN        Y     NaN
#
#                                              Full Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
# 891                                             Rohith     NaN  24.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  last_name  \
# 0      1.0    0.0         A/5 21171   7.2500        S     Braund
# 1      1.0    0.0          PC 17599  71.2833        C    Cumings
# 2      0.0    0.0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3      1.0    0.0            113803  53.1000        S   Futrelle
# 4      0.0    0.0            373450   8.0500        S      Allen
# ..     ...    ...               ...      ...      ...        ...
# 887    0.0    0.0            112053  30.0000        S     Graham
# 888    1.0    2.0        W./C. 6607  23.4500        S   Johnston
# 889    0.0    0.0            111369  30.0000        C       Behr
# 890    0.0    0.0            370376   7.7500        Q     Dooley
# 891    NaN    NaN               NaN      NaN      NaN        NaN
#
#                                       first_name
# 0                                Mr. Owen Harris
# 1     Mrs. John Bradley (Florence Briggs Thayer)
# 2                                    Miss. Laina
# 3             Mrs. Jacques Heath (Lily May Peel)
# 4                              Mr. William Henry
# ..                                           ...
# 887                         Miss. Margaret Edith
# 888               Miss. Catherine Helen "Carrie"
# 889                              Mr. Karl Howell
# 890                                  Mr. Patrick
# 891                                          NaN
#
# [892 rows x 13 columns]

# %%
df.tail()
# Out:
#      PassengerId Survived  Pclass                                 Full Name  \
# 887        888.0        1     1.0              Graham, Miss. Margaret Edith
# 888        889.0        0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889        890.0        1     1.0                     Behr, Mr. Karl Howell
# 890        891.0        0     3.0                       Dooley, Mr. Patrick
# 891          NaN        Y     NaN                                    Rohith
#
#      Gender        Age  SibSp  Parch      Ticket   Fare Embarked last_name  \
# 887  female  19.000000    0.0    0.0      112053  30.00        S    Graham
# 888  female  29.699118    1.0    2.0  W./C. 6607  23.45        S  Johnston
# 889    male  26.000000    0.0    0.0      111369  30.00        C      Behr
# 890    male  32.000000    0.0    0.0      370376   7.75        Q    Dooley
# 891     NaN  24.000000    NaN    NaN         NaN    NaN      NaN       NaN
#
#                           first_name
# 887             Miss. Margaret Edith
# 888   Miss. Catherine Helen "Carrie"
# 889                  Mr. Karl Howell
# 890                      Mr. Patrick
# 891                              NaN

# %%
df.loc[len(df.index)]=row
df.tail()
# Out:
#      PassengerId Survived  Pclass                                 Full Name  \
# 888        889.0        0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889        890.0        1     1.0                     Behr, Mr. Karl Howell
# 890        891.0        0     3.0                       Dooley, Mr. Patrick
# 891          NaN        Y     NaN                                    Rohith
# 892          NaN        Y     NaN                                    Rohith
#
#      Gender        Age  SibSp  Parch      Ticket   Fare Embarked last_name  \
# 888  female  29.699118    1.0    2.0  W./C. 6607  23.45        S  Johnston
# 889    male  26.000000    0.0    0.0      111369  30.00        C      Behr
# 890    male  32.000000    0.0    0.0      370376   7.75        Q    Dooley
# 891     NaN  24.000000    NaN    NaN         NaN    NaN      NaN       NaN
# 892     NaN  24.000000    NaN    NaN         NaN    NaN      NaN       NaN
#
#                           first_name
# 888   Miss. Catherine Helen "Carrie"
# 889                  Mr. Karl Howell
# 890                      Mr. Patrick
# 891                              NaN
# 892                              NaN

# %%
df=df.drop(df.index[-1],axis=0) # Deletes last row
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
#
#                                            Full Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Embarked  last_name  \
# 0    0.0         A/5 21171   7.2500        S     Braund
# 1    0.0          PC 17599  71.2833        C    Cumings
# 2    0.0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3    0.0            113803  53.1000        S   Futrelle
# 4    0.0            373450   8.0500        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
df['Gender']=df['Gender'].map({"male":'0',"female":"1"})

# %%
df.head(5)
# Out:
#    PassengerId Survived  Pclass  \
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
#
#                                            Full Name Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris      0  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.0    1.0
# 2                             Heikkinen, Miss. Laina      1  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.0    1.0
# 4                           Allen, Mr. William Henry      0  35.0    0.0
#
#    Parch            Ticket     Fare Embarked  last_name  \
# 0    0.0         A/5 21171   7.2500        S     Braund
# 1    0.0          PC 17599  71.2833        C    Cumings
# 2    0.0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3    0.0            113803  53.1000        S   Futrelle
# 4    0.0            373450   8.0500        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
df[df["Age"]> 25].head(5)
# Out:
#    PassengerId Survived  Pclass  \
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
# 5          6.0        0     3.0
#
#                                            Full Name Gender        Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.000000    1.0
# 2                             Heikkinen, Miss. Laina      1  26.000000    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.000000    1.0
# 4                           Allen, Mr. William Henry      0  35.000000    0.0
# 5                                   Moran, Mr. James      0  29.699118    0.0
#
#    Parch            Ticket     Fare Embarked  last_name  \
# 1    0.0          PC 17599  71.2833        C    Cumings
# 2    0.0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3    0.0            113803  53.1000        S   Futrelle
# 4    0.0            373450   8.0500        S      Allen
# 5    0.0            330877   8.4583        Q      Moran
#
#                                     first_name
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry
# 5                                    Mr. James

# %%
df[(df["Age"]< 25) & (df["Gender"]=="1")].head(5)
# Out:
#     PassengerId Survived  Pclass                             Full Name Gender  \
# 9          10.0        1     2.0   Nasser, Mrs. Nicholas (Adele Achem)      1
# 10         11.0        1     3.0       Sandstrom, Miss. Marguerite Rut      1
# 14         15.0        0     3.0  Vestrom, Miss. Hulda Amanda Adolfina      1
# 22         23.0        1     3.0           McGowan, Miss. Anna "Annie"      1
# 24         25.0        0     3.0         Palsson, Miss. Torborg Danira      1
#
#      Age  SibSp  Parch   Ticket     Fare Embarked  last_name  \
# 9   14.0    1.0    0.0   237736  30.0708        C     Nasser
# 10   4.0    1.0    1.0  PP 9549  16.7000        S  Sandstrom
# 14  14.0    0.0    0.0   350406   7.8542        S    Vestrom
# 22  15.0    0.0    0.0   330923   8.0292        Q    McGowan
# 24   8.0    3.0    1.0   349909  21.0750        S    Palsson
#
#                       first_name
# 9    Mrs. Nicholas (Adele Achem)
# 10          Miss. Marguerite Rut
# 14   Miss. Hulda Amanda Adolfina
# 22            Miss. Anna "Annie"
# 24          Miss. Torborg Danira

# %%
def save_first(age):
    if age<15:
        return 1
    elif age>=15 and age<60:
        return 0
    elif age>=60:
        return 1

# %%
df['save_first']=df['Age'].apply(lambda x: save_first(x))
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            1.0        0     3.0
# 1            2.0        1     1.0
# 2            3.0        1     3.0
# 3            4.0        1     1.0
# 4            5.0        0     3.0
# ..           ...      ...     ...
# 887        888.0        1     1.0
# 888        889.0        0     3.0
# 889        890.0        1     1.0
# 890        891.0        0     3.0
# 891          NaN        Y     NaN
#
#                                              Full Name Gender        Age  \
# 0                              Braund, Mr. Owen Harris      0  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.000000
# 2                               Heikkinen, Miss. Laina      1  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.000000
# 4                             Allen, Mr. William Henry      0  35.000000
# ..                                                 ...    ...        ...
# 887                       Graham, Miss. Margaret Edith      1  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"      1  29.699118
# 889                              Behr, Mr. Karl Howell      0  26.000000
# 890                                Dooley, Mr. Patrick      0  32.000000
# 891                                             Rohith    NaN  24.000000
#
#      SibSp  Parch            Ticket     Fare Embarked  last_name  \
# 0      1.0    0.0         A/5 21171   7.2500        S     Braund
# 1      1.0    0.0          PC 17599  71.2833        C    Cumings
# 2      0.0    0.0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3      1.0    0.0            113803  53.1000        S   Futrelle
# 4      0.0    0.0            373450   8.0500        S      Allen
# ..     ...    ...               ...      ...      ...        ...
# 887    0.0    0.0            112053  30.0000        S     Graham
# 888    1.0    2.0        W./C. 6607  23.4500        S   Johnston
# 889    0.0    0.0            111369  30.0000        C       Behr
# 890    0.0    0.0            370376   7.7500        Q     Dooley
# 891    NaN    NaN               NaN      NaN      NaN        NaN
#
#                                       first_name  save_first
# 0                                Mr. Owen Harris           0
# 1     Mrs. John Bradley (Florence Briggs Thayer)           0
# 2                                    Miss. Laina           0
# 3             Mrs. Jacques Heath (Lily May Peel)           0
# 4                              Mr. William Henry           0
# ..                                           ...         ...
# 887                         Miss. Margaret Edith           0
# 888               Miss. Catherine Helen "Carrie"           0
# 889                              Mr. Karl Howell           0
# 890                                  Mr. Patrick           0
# 891                                          NaN           0
#
# [892 rows x 14 columns]

# %%
df['save_first']=df['Age'].apply(lambda x: save_first(x))
df_2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/attasilchitwirote/BU/Workshop/python-for-analytics/eda_titanic.ipynb Cell 28 in <module>
#       <a href='vscode-notebook-cell:/Users/attasilchitwirote/BU/Workshop/python-for-analytics/eda_titanic.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> df['save_first']=df['Age'].apply(lambda x: save_first(x))
# ----> <a href='vscode-notebook-cell:/Users/attasilchitwirote/BU/Workshop/python-for-analytics/eda_titanic.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> df_2.head()
#
# NameError: name 'df_2' is not defined

# %%
df_1 = df[['Age','Survived','Gender']]
df_1.head()
# Out:
#     Age Survived Gender
# 0  22.0        0      0
# 1  38.0        1      1
# 2  26.0        1      1
# 3  35.0        1      1
# 4  35.0        0      0

# %%
df_2 = df.iloc[0:100,:]
df_2.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
#
#                                            Full Name Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris      0  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.0    1.0
# 2                             Heikkinen, Miss. Laina      1  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.0    1.0
# 4                           Allen, Mr. William Henry      0  35.0    0.0
#
#    Parch            Ticket     Fare Embarked  last_name  \
# 0    0.0         A/5 21171   7.2500        S     Braund
# 1    0.0          PC 17599  71.2833        C    Cumings
# 2    0.0  STON/O2. 3101282   7.9250        S  Heikkinen
# 3    0.0            113803  53.1000        S   Futrelle
# 4    0.0            373450   8.0500        S      Allen
#
#                                     first_name  save_first
# 0                              Mr. Owen Harris           0
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0
# 2                                  Miss. Laina           0
# 3           Mrs. Jacques Heath (Lily May Peel)           0
# 4                            Mr. William Henry           0

# %%
df_2 = df.iloc[0:100, [0,1,2]]
df_2.head()
# Out:
#    PassengerId Survived  Pclass
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0

# %%
df_2 = df.loc[0:100, ['Age','Survived','Gender']]
df_2.head()
# Out:
#     Age Survived Gender
# 0  22.0        0      0
# 1  38.0        1      1
# 2  26.0        1      1
# 3  35.0        1      1
# 4  35.0        0      0

# %%
df=df.sort_values(by=['Age'],ascending=False)
df.head()
# Out:
#      PassengerId Survived  Pclass                             Full Name  \
# 630        631.0        1     1.0  Barkworth, Mr. Algernon Henry Wilson
# 851        852.0        0     3.0                   Svensson, Mr. Johan
# 96          97.0        0     1.0             Goldschmidt, Mr. George B
# 493        494.0        0     1.0               Artagaveytia, Mr. Ramon
# 116        117.0        0     3.0                  Connors, Mr. Patrick
#
#     Gender   Age  SibSp  Parch    Ticket     Fare Embarked     last_name  \
# 630      0  80.0    0.0    0.0     27042  30.0000        S     Barkworth
# 851      0  74.0    0.0    0.0    347060   7.7750        S      Svensson
# 96       0  71.0    0.0    0.0  PC 17754  34.6542        C   Goldschmidt
# 493      0  71.0    0.0    0.0  PC 17609  49.5042        C  Artagaveytia
# 116      0  70.5    0.0    0.0    370369   7.7500        Q       Connors
#
#                      first_name  save_first
# 630   Mr. Algernon Henry Wilson           1
# 851                   Mr. Johan           1
# 96                 Mr. George B           1
# 493                   Mr. Ramon           1
# 116                 Mr. Patrick           1

# %%
df=df.sort_values(by=['Age', 'Survived'],ascending=False)
df[15:20]
# Out:
#      PassengerId Survived  Pclass                                  Full Name  \
# 829        830.0        1     1.0  Stone, Mrs. George Nelson (Martha Evelyn)
# 570        571.0        1     2.0                         Harris, Mr. George
# 555        556.0        0     1.0                         Wright, Mr. George
# 252        253.0        0     1.0                  Stead, Mr. William Thomas
# 625        626.0        0     1.0                      Sutton, Mr. Frederick
#
#     Gender   Age  SibSp  Parch       Ticket     Fare Embarked last_name  \
# 829      1  62.0    0.0    0.0       113572  80.0000        S     Stone
# 570      0  62.0    0.0    0.0  S.W./PP 752  10.5000        S    Harris
# 555      0  62.0    0.0    0.0       113807  26.5500        S    Wright
# 252      0  62.0    0.0    0.0       113514  26.5500        S     Stead
# 625      0  61.0    0.0    0.0        36963  32.3208        S    Sutton
#
#                               first_name  save_first
# 829   Mrs. George Nelson (Martha Evelyn)           1
# 570                           Mr. George           1
# 555                           Mr. George           1
# 252                   Mr. William Thomas           1
# 625                        Mr. Frederick           1
